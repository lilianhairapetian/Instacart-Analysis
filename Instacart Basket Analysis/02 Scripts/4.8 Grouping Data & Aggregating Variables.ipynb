# %% [markdown]
# ## Importing Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
data_path=r'/Users/Lilian/Downloads/Data Analytics Course/Data Analytics Immersion/Acheivement 4/04-2024 Instacart Basket Analysis/'

# %%
orders_products_merge = pd.read_pickle(os.path.join(data_path,'02 Data','Prepared Data','df_ords_prods_merge_new_variables.pkl'))

# %%
df = orders_products_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138    prior            28          6                 11
# 1   1977647      138    prior            30          6                 17
# 2    389851      709    prior             2          0                 21
# 3    652770      764    prior             1          3                 13
# 4   1813452      764    prior             3          4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# 0                     3.0                  5          0   both
# 1                    20.0                  1          1   both
# 2                     6.0                 20          0   both
# 3                     NaN                 10          0   both
# 4                     9.0                 11          1   both
#
#      busiest_days busiest_period_of_day
# 0  Regularly busy           Most orders
# 1  Regularly busy           Most orders
# 2    Busiest days        Average orders
# 3    Slowest days           Most orders
# 4    Slowest days           Most orders

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
# alternative way to aggregate: 
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
# producting more statistics at the same time
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %%
orders_products_merge['max_order'] = orders_products_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/qs/9rqsgdxj377_cxzw1z92pxbh0000gn/T/ipykernel_17220/1239761660.py:1: FutureWarning: The provided callable <function max at 0x1123ded40> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   orders_products_merge['max_order'] = orders_products_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
orders_products_merge.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# ..         ...                         ...       ...            ...     ...
# 95           1  Chocolate Sandwich Cookies        61             19     5.8
# 96           1  Chocolate Sandwich Cookies        61             19     5.8
# 97           1  Chocolate Sandwich Cookies        61             19     5.8
# 98           1  Chocolate Sandwich Cookies        61             19     5.8
# 99           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    3139998      138    prior            28          6                 11
# 1    1977647      138    prior            30          6                 17
# 2     389851      709    prior             2          0                 21
# 3     652770      764    prior             1          3                 13
# 4    1813452      764    prior             3          4                 17
# ..       ...      ...      ...           ...        ...                ...
# 95    602103    10831    prior             8          3                 11
# 96     49629    11119    prior            18          1                 14
# 97    317888    11186    prior            13          5                 16
# 98    682486    11243    prior            16          3                 13
# 99   2861386    11448    prior            10          2                 15
#
#     days_since_prior_order  add_to_cart_order  reordered _merge  \
# 0                      3.0                  5          0   both
# 1                     20.0                  1          1   both
# 2                      6.0                 20          0   both
# 3                      NaN                 10          0   both
# 4                      9.0                 11          1   both
# ..                     ...                ...        ...    ...
# 95                    23.0                  5          0   both
# 96                    30.0                  1          0   both
# 97                     2.0                  8          0   both
# 98                     0.0                  2          0   both
# 99                     3.0                  6          0   both
#
#       busiest_days busiest_period_of_day  max_order
# 0   Regularly busy           Most orders         32
# 1   Regularly busy           Most orders         32
# 2     Busiest days        Average orders          5
# 3     Slowest days           Most orders          3
# 4     Slowest days           Most orders          3
# ..             ...                   ...        ...
# 95    Slowest days           Most orders         10
# 96    Busiest days           Most orders         23
# 97  Regularly busy           Most orders         26
# 98    Slowest days           Most orders         43
# 99  Regularly busy           Most orders         21
#
# [100 rows x 18 columns]

# %%
# this command removes limitations of number of rows phyton shows when using the head() function.
pd.options.display.max_rows = None

# %%
orders_products_merge.loc[orders_products_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
orders_products_merge.loc[(orders_products_merge['max_order'] <= 40) & (orders_products_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
orders_products_merge.loc[orders_products_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
orders_products_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
orders_products_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# 20     1540  Regular customer             7
# 21     1540  Regular customer             8
# 22     1540  Regular customer             9
# 23     1540  Regular customer            14
# 24     1540  Regular customer            15
# 25     1540  Regular customer            18
# 26     1540  Regular customer            19
# 27     1540  Regular customer            20
# 28     1540  Regular customer            21
# 29     1540  Regular customer            22
# 30     1540  Regular customer            24
# 31     1540  Regular customer            25
# 32     1540  Regular customer            27
# 33     1540  Regular customer            28
# 34     1598      New customer             1
# 35     1598      New customer             2
# 36     1598      New customer             3
# 37     1647      New customer             1
# 38     1647      New customer             4
# 39     1647      New customer             6
# 40     1647      New customer             8
# 41     1647      New customer             9
# 42     2833      New customer             1
# 43     2850  Regular customer             7
# 44     2857  Regular customer            24
# 45     3010  Regular customer             5
# 46     3029      New customer             1
# 47     3395      New customer             4
# 48     3904      New customer             1
# 49     4006    Loyal customer             2
# 50     4006    Loyal customer             3
# 51     4006    Loyal customer             5
# 52     4006    Loyal customer             9
# 53     4006    Loyal customer            12
# 54     4122  Regular customer            11
# 55     4141      New customer             2
# 56     4343      New customer             1
# 57     4553      New customer             3
# 58     4845  Regular customer             6
# 59     6866      New customer             1
